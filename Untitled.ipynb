# %% [markdown]
# ## Abu Dhabi traffic accident report
# data describing the accident history a condition in Abu Dhabi including the road condition, weather condition, reasons, date, and the kind of the accident
# #### The Data language was Arabic, so after cleaning and taking dummies, i translated to english thru translator library

# %% [markdown]
# ## The Model propose, is to predict the injuries by finding the most effective features
# #### The correlation in the top effective features

# %%
ax = correlations_sample.plot(kind='bar')
ax.set(ylim=[-1, 1], ylabel='pearson correlation');

# %% [markdown]
# ## key findings:
# 1. Unknown surface condition is having high effect in injuries.
# 2. Paved surface is very effective in saving lifes and reducng injuries

# %% [markdown]
# ## The target is unbalanced binary.
# #### So i applied many action according to that:
# 1. Using "weight" balance with logistic regression(lr,l1, l2).
# 2. Resampling the before applying KNN.

# %% [markdown]
# ### The best model which can predict with less confusion, high precision, high variance and high area under the curve score is:
# ## Logistic regression with L1 penalty

# %% [markdown]
# ## possible flaws
#
# ### we need to use different predictive modeling techniques, as still all the models we tried had some high confusion

# %%
import os, seaborn as sns, pandas as pd, numpy as np
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
df = pd.read_excel("Traffic_Accident.xlsx")

# %%
df.head()
# Out:
#    سنة التقرير        وقت التقرير            نوع التقرير المدينة  \
# 0         2018 2018-01-02 19:34:10  حادث سير بدون إصابات   العين
# 1         2018 2018-01-16 21:25:42  حادث سير بدون إصابات  ابوظبي
# 2         2018 2018-01-02 12:33:37  حادث سير بدون إصابات   العين
# 3         2018 2018-01-17 02:50:26  حادث سير بدون إصابات   العين
# 4         2018 2018-01-13 07:09:09  حادث سير بدون إصابات   العين
#
#                                              الشارع                نوع الحادث  \
# 0                            تقاطع إشارات العين مول                صدم متتالي
# 1  IP49 تقاطع راشد بن سعيد آل مكتوم - محمد بن خليفة                 صدم جانبي
# 2                                    دوار ابن خلدون                صدم متتالي
# 3                            تقاطع إشارات العين مول                صدم متتالي
# 4                                       شارع الفلاح  صدم جسم ثابت خارج الطريق
#
#                     الاسباب حالة السطح او الارض حالة الجو
# ...

# %%
df = df.drop('الشارع', axis=1)

# %%
df.columns
# Out:
# Index(['سنة التقرير', 'وقت التقرير ', 'نوع التقرير', 'المدينة', 'نوع الحادث',
#        'الاسباب', 'حالة السطح او الارض', 'حالة الجو'],
#       dtype='object')

# %%
df_uniques = pd.DataFrame([[i, len(df[i].unique())] for i in df.columns], columns=['Variable', 'Unique Values']).set_index('Variable')
df_uniques
# Out:
#                      Unique Values
# Variable
# سنة التقرير                      4
# وقت التقرير                 247284
# نوع التقرير                      3
# المدينة                          3
# نوع الحادث                      19
# الاسباب                         61
# حالة السطح او الارض             10
# حالة الجو                        8

# %%
df = df.drop('وقت التقرير ', axis=1)

# %%
df.describe(include='object')
# Out:
#                  نوع التقرير المدينة نوع الحادث              الاسباب  \
# count                 249695  249695     249695               249695
# unique                     3       3         19                   61
# top     حادث سير بدون إصابات  ابوظبي  صدم جانبي  عدم ترك مسافة كافية
# freq                  247331  140700      75393                63897
#
#        حالة السطح او الارض حالة الجو
# count               249695    249695
# unique                  10         8
# top                   معبد       صحو
# freq                243486    248375

# %%
categorical_variables = list(df_uniques[df_uniques['Unique Values'] <= 61].index)

# %%
categorical_variables
# Out:
# ['سنة التقرير',
#  'نوع التقرير',
#  'المدينة',
#  'نوع الحادث',
#  'الاسباب',
#  'حالة السطح او الارض',
#  'حالة الجو']

# %%
[list(df[i].unique()) for i in categorical_variables]
# Out:
# [[2018, 2019, 2020, 2021],
#  ['حادث سير بدون إصابات', 'حادث سير بإصابات', 'حادث سير ضد مجهول'],
#  ['العين', 'ابوظبي', 'الظفرة'],
#  ['صدم متتالي',
#   'صدم جانبي',
#   'صدم جسم ثابت خارج الطريق',
#   'أخرى(حدد)',
#   'صدم خلفي',
#   'صدم جسم ثابت في الطريق',
#   'صدم عمودي',
#   'صدم جسم غير ثابت في الطريق',
#   'صدم جسم غير ثابت خارج الطريق',
#   'تدهور',
#   'دهس إنسان',
#   'صدم متقابل',
#   'صدم حيوان',
#   'غير معروف',
#   'صدم غير متحرك',
#   'صدم إثناء الدوران',
#   'انفصال مقطورة',
#   'سقوط',
#   'إحتراق'],
#  ['عدم ترك مسافة كافية',
#   'الاهمال وعدم الانتباه',
#   'الرجوع للخلف بدون انتباه',
#   'الإنحراف المفاجئ',
#   'اللامبالاة',
#   'الرجوع للخلف دون التأكد من خلو الطريق',
#   'عدم الإلتزام بخط السير الالزامي',
#   'عدم التقيد بالاشارات المرورية',
#   'عدم تأمين ثبات المركبة أثناء وقوفها',
#   'عدم إفساح الطريق / عدم إعطاء الألوية',
#   'دخول طريق رئيسي دون التأكد من خلوه',
#   'السير عكس الإتجاه',
#   'عدم تقدير مستعملي الطريق',
#   'عيوب أخرى (حدد)',
# ...

# %%
df_1 = pd.get_dummies(df, columns = categorical_variables, drop_first=False)

# %%
df_1.columns=df_1.columns.str.replace('_',' ')

# %%
np.array(df_1.columns)
# Out:
# array(['سنة التقرير 2018', 'سنة التقرير 2019', 'سنة التقرير 2020',
#        'سنة التقرير 2021', 'نوع التقرير حادث سير بإصابات',
#        'نوع التقرير حادث سير بدون إصابات',
#        'نوع التقرير حادث سير ضد مجهول', 'المدينة ابوظبي',
#        'المدينة الظفرة', 'المدينة العين', 'نوع الحادث أخرى(حدد)',
#        'نوع الحادث إحتراق', 'نوع الحادث انفصال مقطورة',
#        'نوع الحادث تدهور', 'نوع الحادث دهس إنسان', 'نوع الحادث سقوط',
#        'نوع الحادث صدم إثناء الدوران', 'نوع الحادث صدم جانبي',
#        'نوع الحادث صدم جسم ثابت خارج الطريق',
#        'نوع الحادث صدم جسم ثابت في الطريق',
#        'نوع الحادث صدم جسم غير ثابت خارج الطريق',
#        'نوع الحادث صدم جسم غير ثابت في الطريق', 'نوع الحادث صدم حيوان',
#        'نوع الحادث صدم خلفي', 'نوع الحادث صدم عمودي',
#        'نوع الحادث صدم غير متحرك', 'نوع الحادث صدم متتالي',
#        'نوع الحادث صدم متقابل', 'نوع الحادث غير معروف',
#        'الاسباب إنحجاب الرؤية', 'الاسباب إنفجار إطار',
# ...

# %%
import translators as ts
# Out:
# Using United Arab Emirates server backend.

# %%
# changing the columns name to English, it's took long time
df_1.columns = [ts.google(i) for i in df_1.columns]

# %%
np.array(df_1.columns)
# Out:
# array(['Year report 2018', 'Year report 2019', 'Year report 2020',
#        'Year report 2021', 'The type of report is a traffic accident',
#        'The type of report is a traffic accident without injuries',
#        'Type of report traffic against anonymous',
#        'The city of Abu Dhabi', 'City Al Dhafra', 'City Al Ain',
#        'Other incident type (Select)', 'The type of incident is burning',
#        'Type of incident detachable trailer',
#        'Type of incident deterioration', 'The type of incident run over',
#        'Type of incident fall',
#        'The type of incident was shocked by rotating',
#        'The type of incident is shocked',
#        'The type of incident shocked a steady body out of the road',
#        'The type of incident shocked a steady body in the way',
#        'The type of incident shock an unstable body out of the road',
#        'The type of incident shock an unstable body in the way',
#        'The type of accident shock an animal',
# ...

# %%
df_1
# Out:
#         Year report 2018  Year report 2019  Year report 2020  \
# 0                      1                 0                 0
# 1                      1                 0                 0
# 2                      1                 0                 0
# 3                      1                 0                 0
# 4                      1                 0                 0
# ...                  ...               ...               ...
# 249690                 0                 0                 0
# 249691                 0                 1                 0
# 249692                 0                 0                 1
# 249693                 0                 0                 1
# 249694                 1                 0                 0
#
#         Year report 2021  The type of report is a traffic accident  \
# 0                      0                                         0
# 1                      0                                         0
# ...

# %% [markdown]
# ##  saving the data after getting the dummies and translate the columns.

# %%
outputfile = 'new_acc_report.csv'
df_1.to_csv(outputfile, index=False)

# %% [markdown]
# ## correct the mistranslated by translators.google

# %%
import os, seaborn as sns, pandas as pd, numpy as np

# %%
data = pd.read_csv('new_acc_report.csv')

# %%
data = data.drop('The type of report is a traffic accident without injuries', axis=1)
data = data.rename(columns={'The type of report is a traffic accident': 'with injuries'})

# %%
data = data.rename(columns={'Air condition':'fine weather', 'Atmospheric atmosphere': 'dusty weather', 'Surface or earth status':'humpy surface', 'Endoscopy causes':'unknown reason',
       'Causes drive a vehicle in a way that presents his life':'driving in dangerous way','Surface or other land status (select)':'Surface condition other',
       'Surface or earth territory':'Dusty Surface', 'Surface or ground condition':'dry Surface',
       'Surface or earth condition is non-temple':'unpaved Surface',
       'Surface state or earth laugh': 'wet Surface', 'Surface or ground condition':'unknown Surface condition',
       'Surface or ground condition temple': 'paved Surface'})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249695 entries, 0 to 249694
# Columns: 107 entries, Year report 2018 to Air condition is rainy
# dtypes: int64(107)
# memory usage: 203.8 MB

# %%
data.describe().T
# Out:
#                               count      mean       std  min  25%  50%  75%  \
# Year report 2018           249695.0  0.323571  0.467839  0.0  0.0  0.0  1.0
# Year report 2019           249695.0  0.320299  0.466592  0.0  0.0  0.0  1.0
# Year report 2020           249695.0  0.239288  0.426650  0.0  0.0  0.0  0.0
# Year report 2021           249695.0  0.116843  0.321233  0.0  0.0  0.0  0.0
# with injuries              249695.0  0.008374  0.091127  0.0  0.0  0.0  0.0
# ...                             ...       ...       ...  ...  ...  ...  ...
# Storm atmosphere           249695.0  0.000064  0.008005  0.0  0.0  0.0  0.0
# The weather is cloudy      249695.0  0.000080  0.008949  0.0  0.0  0.0  0.0
# The atmosphere is unknown  249695.0  0.000072  0.008490  0.0  0.0  0.0  0.0
# dusty weather              249695.0  0.000324  0.018008  0.0  0.0  0.0  0.0
# Air condition is rainy     249695.0  0.003340  0.057697  0.0  0.0  0.0  0.0
#
#                            max
# ...

# %%
data['with injuries'].value_counts()
# Out:
# 0    247604
# 1      2091
# Name: with injuries, dtype: int64

# %% [markdown]
# ## saving the final dataset

# %%
outputfile = 'final_acc_report.csv'
data.to_csv(outputfile, index=False)

# %% [markdown]
# ### splitting the data and finding the correlation between the features

# %%
X = data.drop('with injuries', axis=1)
y = data['with injuries']

# %%
inj = (data['with injuries'] == 1).astype(int)
fields = list(data.drop('with injuries', axis=1))
correlations = data[fields].corrwith(inj)
correlations.sort_values(inplace=True)
correlations
# Out:
# paved Surface                                                                 -0.509712
# fine weather                                                                  -0.049058
# The type of incident is consumed                                              -0.048080
# Causes Back without attention                                                 -0.036134
# The type of incident is shocked                                               -0.027604
#                                                                                  ...
# Reasons not to give priority to cross infantry                                 0.136413
# Speed causes without taking into account road conditions                       0.157144
# The reasons for the road while driving the vehicle in any picture they were    0.299938
# The type of incident run over                                                  0.324538
# unknown Surface condition                                                      0.528471
# ...

# %%
correlations_sample = pd.concat([correlations.sort_values(ascending=False)[:15], correlations.sort_values(ascending=False)[-15:]])

# %%
correlations_sample
# Out:
# unknown Surface condition                                                      0.528471
# The type of incident run over                                                  0.324538
# The reasons for the road while driving the vehicle in any picture they were    0.299938
# Speed causes without taking into account road conditions                       0.157144
# Reasons not to give priority to cross infantry                                 0.136413
# Reasons do not estimate the way users                                          0.107978
# Reasons for driving without driving license at all                             0.106882
# Type of incident deterioration                                                 0.093127
# Reasons driving under impact or anesthetic                                     0.092150
# Reasons for sudden deviation                                                   0.069645
# The weather is cloudy                                                          0.067929
# ...

# %%
ax = correlations_sample.plot(kind='bar')
ax.set(ylim=[-1, 1], ylabel='pearson correlation');

# %%
feature_cols = X.columns
corr_values = data[feature_cols].corr()

# %%
tril_index = np.tril_indices_from(corr_values)

# %%
for coord in zip(*tril_index):
    corr_values.iloc[coord[0], coord[1]] = np.NaN

# %%
corr_values
# Out:
#                                           Year report 2018  Year report 2019  \
# Year report 2018                                       NaN          -0.47478
# Year report 2019                                       NaN               NaN
# Year report 2020                                       NaN               NaN
# Year report 2021                                       NaN               NaN
# Type of report traffic against anonymous               NaN               NaN
# ...                                                    ...               ...
# Storm atmosphere                                       NaN               NaN
# The weather is cloudy                                  NaN               NaN
# The atmosphere is unknown                              NaN               NaN
# dusty weather                                          NaN               NaN
# Air condition is rainy                                 NaN               NaN
#
# ...

# %%
corr_values = (corr_values
               .stack()
               .to_frame()
               .reset_index()
               .rename(columns={'level_0':'feature1',
                                'level_1':'feature2',
                                0:'correlation'}))

# %%
corr_values['abs_correlation'] = corr_values.correlation.abs()

# %%
corr_values
# Out:
#                        feature1                                  feature2  \
# 0              Year report 2018                          Year report 2019
# 1              Year report 2018                          Year report 2020
# 2              Year report 2018                          Year report 2021
# 3              Year report 2018  Type of report traffic against anonymous
# 4              Year report 2018                     The city of Abu Dhabi
# ...                         ...                                       ...
# 5560      The weather is cloudy                             dusty weather
# 5561      The weather is cloudy                    Air condition is rainy
# 5562  The atmosphere is unknown                             dusty weather
# 5563  The atmosphere is unknown                    Air condition is rainy
# 5564              dusty weather                    Air condition is rainy
#
#       correlation  abs_correlation
# 0       -0.474780         0.474780
# ...

# %%
corr_values.sort_values(by='abs_correlation', ascending=False).query('abs_correlation>0.8')
# Out:
#                               feature1                         feature2  \
# 516              The city of Abu Dhabi                      City Al Ain
# 2294  The type of incident is consumed  The reasons are not left enough
# 5448         unknown Surface condition                    paved Surface
# 5331                    unknown reason        The atmosphere is unknown
#
#       correlation  abs_correlation
# 516     -0.966086         0.966086
# 2294     0.946473         0.946473
# 5448    -0.894973         0.894973
# 5331     0.816487         0.816487

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_context('talk')
sns.set_style('white')

ax = corr_values.abs_correlation.hist(bins=80, figsize=(12, 8))
ax.set(xlabel='Absolute Correlation', ylabel='Frequency');

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
strat_shuf_split = StratifiedShuffleSplit(n_splits=5, 
                                          test_size=0.3, 
                                          random_state=42)

train_idx, test_idx = next(strat_shuf_split.split(data[feature_cols], data['with injuries']))

# Create the dataframes
X_train = data.loc[train_idx, feature_cols]
y_train = data.loc[train_idx, 'with injuries']

X_test  = data.loc[test_idx, feature_cols]
y_test  = data.loc[test_idx, 'with injuries']

# %%
y_train.value_counts(normalize=True)
# Out:
# 0    0.991624
# 1    0.008376
# Name: with injuries, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# 0    0.99163
# 1    0.00837
# Name: with injuries, dtype: float64

# %% [markdown]
# ## As the dataset is unbalanced dataset, i will add parameter class_weight="balanced" as a kind of solution, that will keep repeating the low class to make it equal to other class

# %% [markdown]
# ### Logistic Regression (penalty l1 & l2)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(solver='liblinear').fit(X_train, y_train)

# %%
from sklearn.linear_model import LogisticRegressionCV

lr_l1 = LogisticRegressionCV(Cs=[10], class_weight="balanced", cv=4, penalty='l1', solver='liblinear').fit(X_train, y_train)

# %%
lr_l1.coef_
# Out:
# array([[ 0.00000000e+00,  1.10417459e+00,  5.82893665e-01,
#         -4.26919864e-01, -1.61917526e+01,  4.56593165e-01,
#         -1.04684720e+00,  2.31522179e-01, -1.33162880e+01,
#         -5.44075905e+00,  4.65084455e+00,  1.86101246e+00,
#          7.75583030e+00,  1.16609278e-02,  6.92321257e-01,
#          5.24298922e-01, -4.32608320e-01,  1.34477319e+00,
#         -2.21016612e+00, -2.24437535e+00, -5.24324579e-01,
#          3.24111250e+00,  1.85114205e+00, -9.93816112e+00,
#         -1.83457766e+00,  3.56344525e+00, -5.54340864e+00,
#         -3.84599961e+00, -1.74760569e+00,  2.65990591e+00,
#          4.86053553e+00,  1.45894497e+00,  0.00000000e+00,
#          7.38695802e+00,  2.01211455e+00, -4.37368215e-01,
#          1.52124304e+00,  9.11514784e-01,  3.40755301e+00,
#         -2.14663369e+00,  3.75006790e+00, -5.61185104e+00,
#         -4.62429121e+00,  4.41224598e+00, -6.57541560e-01,
#          0.00000000e+00,  2.65569119e+00, -7.14527901e+00,
# ...

# %%
lr_l2 = LogisticRegressionCV(Cs=10, class_weight="balanced", cv=4, penalty='l2', solver='liblinear').fit(X_train, y_train)

# %%
coefficients = list()

coeff_labels = ['lr', 'l1', 'l2']
coeff_models = [lr, lr_l1, lr_l2]

for lab,mod in zip(coeff_labels, coeff_models):
    coeffs = mod.coef_
    coeff_label = pd.Index([lab])
    coefficients.append(pd.DataFrame(coeffs.T, columns=coeff_label))

coefficients = pd.concat(coefficients, axis=1)

coefficients.sample(10)
# Out:
#           lr         l1        l2
# 73  0.534256   3.763208  0.001143
# 36  0.599345   1.521243  0.008108
# 97 -0.251975  -4.029655 -0.000156
# 89 -0.126905   1.130260  0.052226
# 63 -0.787812  -0.107581  0.052812
# 4  -3.169613 -16.191753 -0.007410
# 18 -0.902092  -2.210166 -0.006119
# 15 -0.365011   0.524299 -0.191729
# 59  0.037018   0.000000  0.001642
# 98 -0.217070  -1.612914  0.004727

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.scatterplot(data=coefficients)
# Out:
# <AxesSubplot:>

# %%
y_pred = list()
y_prob = list()

coeff_labels = ['lr', 'l1', 'l2']
coeff_models = [lr, lr_l1, lr_l2]

for lab,mod in zip(coeff_labels, coeff_models):
    y_pred.append(pd.Series(mod.predict(X_test), name=lab))
    y_prob.append(pd.Series(mod.predict_proba(X_test).max(axis=1), name=lab))
    
y_pred = pd.concat(y_pred, axis=1)
y_prob = pd.concat(y_prob, axis=1)

y_pred.sample(10)
# Out:
#        lr  l1  l2
# 63405   0   0   0
# 49164   0   0   0
# 67117   0   0   0
# 12028   0   0   0
# 23696   0   0   0
# 14099   0   0   0
# 40580   0   0   0
# 12790   0   0   0
# 5175    0   0   0
# 68552   0   0   0

# %%
y_prob.head(10)
# Out:
#          lr        l1        l2
# 0  0.999973  0.999952  0.796117
# 1  0.999621  0.961935  0.785245
# 2  0.999883  0.996623  0.762441
# 3  0.999727  0.990985  0.740582
# 4  0.999252  0.983978  0.795579
# 5  0.999533  0.975042  0.740827
# 6  0.999448  0.971729  0.783558
# 7  0.999252  0.983978  0.795579
# 8  0.999586  0.992358  0.836324
# 9  0.999954  1.000000  0.742813

# %%
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score
from sklearn.preprocessing import label_binarize

# %%
metrics = list()
cm = dict()

for lab in coeff_labels:

    # Preciision, recall, f-score from the multi-class support function
    precision, recall, fscore, _ = score(y_test, y_pred[lab], average='weighted')
    
    # The usual way to calculate accuracy
    accuracy = accuracy_score(y_test, y_pred[lab])
    
    # ROC-AUC scores can be calculated by binarizing the data
    auc = roc_auc_score(label_binarize(y_test, classes=[0,1]),
              label_binarize(y_pred[lab], classes=[0,1]), 
              average='weighted')
    
    # Last, the confusion matrix
    cm[lab] = confusion_matrix(y_test, y_pred[lab])
    
    metrics.append(pd.Series({'precision':precision, 'recall':recall, 
                              'fscore':fscore, 'accuracy':accuracy,
                              'auc':auc}, 
                             name=lab))

metrics = pd.concat(metrics, axis=1)

# %%
metrics
# Out:
#                  lr        l1        l2
# precision  0.994099  0.993289  0.993180
# recall     0.994620  0.976038  0.982766
# fscore     0.994260  0.982841  0.986793
# accuracy   0.994620  0.976038  0.982766
# auc        0.779049  0.961824  0.929634

# %% [markdown]
# ### The highest area under the curve score is logistic regression with penalty
#
# ## L1

# %%
fig, axList = plt.subplots(nrows=1, ncols=4)
axList = axList.flatten()
fig.set_size_inches(19, 5)
sns.set(font_scale=1.4)
axList[-1].axis('off')

for ax,lab in zip(axList[:-1], coeff_labels):
    sns.heatmap(cm[lab], ax=ax, annot=True, fmt='d', cmap="Blues", vmin=200, vmax=2000);
    ax.set(title=lab);
    
plt.tight_layout()

# %% [markdown]
# ### looks like our target getting confused between(0,1) with injuries and without injuries, in all models.

# %% [markdown]
# .................
# ## Splitting the dataset and apply K Nearest Neighbors

# %%
import os, seaborn as sns, pandas as pd, numpy as np

# %%
data = pd.read_csv('final_acc_report.csv')

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, f1_score

# %%
y, X = data['with injuries'], data.drop(columns='with injuries')

# %%
y.value_counts()
# Out:
# 0    247604
# 1      2091
# Name: with injuries, dtype: int64

# %% [markdown]
# ### Resampling the data in order to convert the dataset to balanced dataset

# %%
n = 2091
sample_yes = data[data['with injuries'] == 1].sample(n=n, replace=False, random_state=0)
sample_no = data[data['with injuries'] == 0].sample(n=n, replace=False, random_state=0)
df = pd.concat([sample_yes, sample_no])

# %%
y, X = df['with injuries'], df.drop(columns='with injuries')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
# Estimate KNN model and report outcomes
knn = KNeighborsClassifier(n_neighbors=3)
knn = knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
# Preciision, recall, f-score from the multi-class support function
print(classification_report(y_test, y_pred))
print('Accuracy score: ', round(accuracy_score(y_test, y_pred), 2))
print('F1 Score: ', round(f1_score(y_test, y_pred), 2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96       819
#            1       0.98      0.93      0.96       854
#
#     accuracy                           0.96      1673
#    macro avg       0.96      0.96      0.96      1673
# weighted avg       0.96      0.96      0.96      1673
#
# Accuracy score:  0.96
# F1 Score:  0.96

# %%
sns.set_palette(sns.color_palette())
_, ax = plt.subplots(figsize=(12,12))
ax = sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', annot_kws={"size": 40, "weight": "bold"})  
labels = [0, 1]
ax.set_xticklabels(labels, fontsize=25);
ax.set_yticklabels(labels[::-1], fontsize=25);
ax.set_ylabel('Prediction', fontsize=30);
ax.set_xlabel('True', fontsize=30)
# Out:
# Text(0.5, 80.5, 'True')

# %% [markdown]
# ### Using gridsearchcv to find the best pram

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
pipe = Pipeline([('knn', KNeighborsClassifier(algorithm='brute'))])
params = {
    'knn__n_neighbors': [3, 5, 7, 9, 13, 17, 21, 25, 29, 37, 45], 
    'knn__weights':['uniform', 'distance']
}
clf = GridSearchCV(estimator=pipe,           
                  param_grid=params, 
                  cv=5,
                  return_train_score=True)
clf.fit(X, y)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('knn',
#                                         KNeighborsClassifier(algorithm='brute'))]),
#              param_grid={'knn__n_neighbors': [3, 5, 7, 9, 13, 17, 21, 25, 29,
#                                               37, 45],
#                          'knn__weights': ['uniform', 'distance']},
#              return_train_score=True)

# %%
clf.best_params_
# Out:
# {'knn__n_neighbors': 21, 'knn__weights': 'distance'}

# %%
knn = clf.best_estimator_
knn = knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
# Preciision, recall, f-score from the multi-class support function
print(classification_report(y_test, y_pred))
print('Accuracy score: ', round(accuracy_score(y_test, y_pred), 2))
print('F1 Score: ', round(f1_score(y_test, y_pred), 2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       819
#            1       0.97      0.94      0.96       854
#
#     accuracy                           0.96      1673
#    macro avg       0.96      0.96      0.96      1673
# weighted avg       0.96      0.96      0.96      1673
#
# Accuracy score:  0.96
# F1 Score:  0.96

# %%
sns.set_palette(sns.color_palette())
_, ax = plt.subplots(figsize=(12,12))
ax = sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', annot_kws={"size": 40, "weight": "bold"})  
labels = [0, 1]
ax.set_xticklabels(labels, fontsize=25);
ax.set_yticklabels(labels[::-1], fontsize=25);
ax.set_ylabel('Prediction', fontsize=30);
ax.set_xlabel('True', fontsize=30)
# Out:
# Text(0.5, 80.5, 'True')

# %% [markdown]
# ### Another  way to find best model thru F1-score and error

# %%
max_k = 40
f1_scores = list()
error_rates = list() # 1-accuracy

for k in range(1, max_k):
    
    knn = KNeighborsClassifier(n_neighbors=k, weights='distance')
    knn = knn.fit(X_train, y_train)
    
    y_pred = knn.predict(X_test)
    f1 = f1_score(y_pred, y_test)
    f1_scores.append((k, round(f1_score(y_test, y_pred), 4)))
    error = 1-round(accuracy_score(y_test, y_pred), 4)
    error_rates.append((k, error))
    
f1_results = pd.DataFrame(f1_scores, columns=['K', 'F1 Score'])
error_results = pd.DataFrame(error_rates, columns=['K', 'Error Rate'])

# %%
f1_results.sort_values(by='F1 Score', ascending=False).head(3)
# Out:
#      K  F1 Score
# 13  14    0.9584
# 2    3    0.9582
# 11  12    0.9578

# %%
error_results.sort_values(by='Error Rate').head(3)
# Out:
#      K  Error Rate
# 13  14      0.0418
# 2    3      0.0418
# 15  16      0.0424

# %%
sns.set_context('talk')
sns.set_style('ticks')

plt.figure(dpi=300)
ax = f1_results.set_index('K').plot(figsize=(12, 12), linewidth=6)
ax.set(xlabel='K', ylabel='F1 Score')
ax.set_xticks(range(1, max_k, 2));
plt.title('KNN F1 Score')
plt.savefig('knn_f1.png')

# %%
sns.set_context('talk')
sns.set_style('ticks')

plt.figure(dpi=300)
ax = error_results.set_index('K').plot(figsize=(12, 12), linewidth=6)
ax.set(xlabel='K', ylabel='Error Rate')
ax.set_xticks(range(1, max_k, 2))
plt.title('KNN Elbow Curve')
plt.savefig('knn_elbow.png')

# %% [markdown]
# ## Hence the best pram (k_neighber = 3 & weights='distance')

# %% [markdown]
# ............................................

# %% [markdown]
# ## Applying Support Vector Machines
